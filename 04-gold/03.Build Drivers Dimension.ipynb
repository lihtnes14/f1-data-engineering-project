# %%
# %run ../00-common/01.environment-config

# %%
target_table = f"{catlog_name}.{gold_schema}.dim_drivers"

# %%
from pyspark.sql import functions as F

# %%
drivers_df = spark.table(f"{catlog_name}.{silver_schema}.drivers")
ref_nationality_region_df = spark.table(f"{catlog_name}.{gold_schema}.ref_nationality_region")

# %%
dim_drivers_df = (
    drivers_df
        .join(
            ref_nationality_region_df,
            drivers_df.nationality == ref_nationality_region_df.nationality,
            "left"
        )
        .select(
            drivers_df.driver_id,
            drivers_df.driver_name,
            drivers_df.driver_date_of_birth,
            drivers_df.nationality,
            ref_nationality_region_df.region.alias("nationality_region")
            )
)

# %%
display(dim_drivers_df)

# %%
(
    dim_drivers_df
        .write
        .format("delta")
        .mode("overwrite")
        .saveAsTable(target_table)
)

# %%
display(spark.table(target_table))
